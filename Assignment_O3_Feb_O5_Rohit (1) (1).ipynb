# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
  x = np.arange( 1,11,1)
  y = x ** 2 
  plt.plot(x,y)

# %%
  x = np.arange( 1,11,1)
  y = x ** 2 
  plt.plot(x,y)
  plt.xlabel( ' X-axis ( Numbers ) ' ) 
  plt.ylabel( ' Y-axis ( Squares ) ' ) 
  plt.xlabel( ' X-axis ( Simple Line Plot ) ' ) 
  plt.show()

# %%
plt.plot(x, y, color='black', linestyle='--', marker='o')
plt.xlabel('Numbers')
plt.ylabel('Squares')
plt.title('Customized Line Plot')
plt.grid(True)  
plt.show()

# %%
# Sample Data Of KumbhMela 2025
days = ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5', 'Day 6', 'Day 7', 'Day 8', 'Day 9', 'Day 10' ]
visitors = np.random.randint(50000, 200000, size=10)
cities = ['Prayagraj', 'Varanasi', 'Lucknow', 'Kanpur', 'Agra', 'KedarNath', 'Badrinath', 'Ghrushneshwar', 'Kashi', 'Haridwar']
participants = np.random.randint(3000, 15000, size=10)
visitors
# Out:
# array([141044,  85104, 156609,  54354, 102100, 167186,  53233,  71554,
#        155871, 166490])

# %%
 # dataframes
df_visitors = pd.DataFrame({'Day': days, 'Visitors': visitors})
df_participants = pd.DataFrame({'City': cities, 'Participants': participants})
df_visitors
df_participants
# Out:
#             City  Participants
# 0      Prayagraj          3892
# 1       Varanasi         10649
# 2        Lucknow          9089
# 3         Kanpur         13940
# 4           Agra         14161
# 5      KedarNath          7784
# 6      Badrinath         13594
# 7  Ghrushneshwar          6925
# 8          Kashi          3273
# 9       Haridwar         14774

# %%
plt.figure(figsize=(10, 10))
plt.plot(df_visitors['Day'], df_visitors['Visitors'], marker='o', color='black')
plt.xlabel(' X_axis( Days ) ' )
plt.ylabel(' Y_axis( Number of Visitors ) ')
plt.title('Visitors During Khubh Mela Over Days')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.bar(df_participants['City'], df_participants['Participants'], color='skyblue')
plt.xlabel('Cities')
plt.ylabel('Number of Participants')
plt.title('Participants from Different Cities - Khubh Mela')
plt.show()

# %%
# chart : Distribution of Participants by City
plt.figure(figsize=(10, 10))
plt.pie(df_participants['Participants'], labels=df_participants['City'], autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Participant Distribution by City')
plt.show()

# %%
# Multiple Plots in One Figure
plt.figure(figsize=(20, 5))

# Subplot 1: Line Plot
plt.subplot(1, 2, 1)
plt.plot(df_visitors['Day'], df_visitors['Visitors'], marker='s', color='yellow')
plt.title('Daily Visitors')
plt.xlabel('Days')
plt.ylabel('Visitors')

# Subplot 2: Bar Chart
plt.subplot(1, 2, 2)
plt.bar(df_participants['City'], df_participants['Participants'], color='red')
plt.title('City-wise Participants')
plt.xlabel('Cities')
plt.ylabel('Participants')

plt.tight_layout()
plt.show()
 # Adding Multiple Lines 
plt.figure(figsize=(8, 5))
x = np.arange(1, 11)
plt.plot(x, visitors, label='Visitors Trend', linestyle='-', marker='o')
plt.plot(x, participants, label='Participants Trend', linestyle='--', marker='s')
plt.xlabel('Days/Cities Index')
plt.ylabel('Count')
plt.title('Visitors & Participants Trend - Khubh Mela')
plt.legend()
plt.grid(True)
plt.show()

# Saving a Plot
plt.figure(figsize=(8, 5))
plt.plot(df_visitors['Day'], df_visitors['Visitors'], color='grey')
plt.title('Saved Plot Example - Visitors Trend')
plt.savefig('khubh_mela_visitors_trend.png')
plt.show()
